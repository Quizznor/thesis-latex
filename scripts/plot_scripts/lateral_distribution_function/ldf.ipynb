# %%
from utils.binaries import *
from utils.plotting import *
# Out:
# 00:36:33 (  +613ms) [INFO   ] -- import logging
# 00:36:33 (  +123ms) [INFO   ] -- import numpy as np
# 00:36:33 (    +6ms) [INFO   ] -- import uncertainties
# 00:36:33 (  +310ms) [INFO   ] -- import pandas as pd
# 00:36:33 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 00:36:33 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 00:36:34 (  +334ms) [INFO   ] -- import matplotlib.pyplot as plt
# 00:36:34 (  +606ms) [INFO   ] -- import seaborn as so
# 00:36:34 (    +2ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 00:36:34 (    +0ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 00:36:34 (    +1ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 00:36:34 (    +0ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 00:36:34 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# ...

# %%
def ldf(r, s1000, beta):

    rs = 100
    first = np.float_power(3.47, beta)
    second = r/rs * (1 + r/rs)

    return first * s1000 * np.float_power(second, -beta)

# %%
R = np.geomspace(10, 10000, 100)

for beta in np.arange(0.1, 1.11, 0.25):
    plt.plot(R, ldf(R, 100, beta), ls='solid', marker='none')

plt.yscale("log")
plt.xscale("log")
