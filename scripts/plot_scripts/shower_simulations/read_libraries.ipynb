# %%
from utils.binaries import *
from utils.plotting import *

# Data gathered from CORSIKA 8 apptainer with /opt/corsika8/install/bin/c8_air_shower binary
# c8_air_shower -E 100000 -p 1000260560 -M SIBYLL-2.3d -N 1 -f 1e17_sibyll_iron
# Out:
# 18:47:56 ( +199.1s) [INFO   ] -- import logging
# 18:47:56 (  +368ms) [INFO   ] -- import numpy as np
# 18:47:56 (   +39ms) [INFO   ] -- import uncertainties
# 18:47:58 (   +1.4s) [INFO   ] -- import pandas as pd
# 18:47:58 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 18:47:58 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 18:47:58 (    +2ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 18:47:58 (    +1ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 18:47:58 (    +0ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 18:47:58 (    +1ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 18:47:58 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# 18:47:58 (    +1ms) [INFO   ] -- set OFLN_PATH = PosixPath('/home/filip/Public/offline/install')
# 18:47:59 (  +603ms) [INFO   ] -- import matplotlib.pyplot as plt
# 18:47:59 (  +861ms) [INFO   ] -- import seaborn as so
# 18:47:59 (    +1ms) [INFO   ] -- import plotting.tools as plot
# 18:47:59 (    +8ms) [DEBUG  ] -- font size set to 9.5
# 18:47:59 (    +0ms) [DEBUG  ] -- label size set to 13.0
# 18:47:59 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 18:47:59 (    +0ms) [DEBUG  ] -- markersize set to 2.0
# 18:47:59 (    +1ms) [DEBUG  ] -- usetex set to False

# %%
set_plt_style("triple")

select_em = lambda df: df[(df["pdg"] == 22) | (df["pdg"] == 11) | (df["pdg"] == -11)]
select_hd = lambda df: df[(df["pdg"] != 22) & (df["pdg"] != 11) & (df["pdg"] != -11)]
r = lambda df: np.sqrt(df['x'].values**2 + df['y'].values**2)

c = {
    'epos_lhc': "k",
    'qgsjet': "r",
    'sibyll': "b"
}

for primary in ['photon', 'proton', 'iron'][::-1]:
    plt.figure()
    for model in ["epos_lhc", 'qgsjet', 'sibyll']:

        try:
            data = pd.read_parquet(f"/home/filip/Public/CORSIKA8/1e17_{model}_{primary}/particles/particles.parquet")

            data_em, data_hd = select_em(data), select_hd(data)
            plt.hist(r(data_em), color=c[model], linestyle='-', 
                     histtype='step', bins=100, range=(0, 2400))

            plt.hist(r(data_hd), color=c[model], linestyle='--', 
                     histtype='step', bins=100, range=(0, 2400))

        except Exception as e:
            print(primary, model, e)
            continue
    
    em = plt.errorbar([], [], c='gray', ls='-', label="EM ($e^\pm$, $\gamma$)", marker='none')
    # leg1 = plt.gca().legend(handles=[em, hd], title=f"{primary.capitalize()} $100$ TeV",
    #                         ncol=2, title_fontsize=6, fontsize=4.5, loc='upper left')
    # plt.gca().add_artist(leg1)

    epos = plt.errorbar([], [], ls='-', label="EPOS LHC", marker='none')
    qgs = plt.errorbar([], [], ls='--', label="QGSJET-II.04", marker='none')
    hd = plt.errorbar([], [], c='gray', ls='--', label="Non-EM", marker='none')
    sibyll = plt.errorbar([], [], ls=':', label="Sibyll-2.3d", marker='none')
    # leg2 = plt.gca().legend(handles=[epos, qgs, sibyll], fontsize=3.6, loc='upper right')
    # plt.gca().add_artist(leg2)
    plt.legend(title=f"{primary.capitalize()} $100$ TeV",
               ncol=2, title_fontsize=6, fontsize=5, loc='upper right')

    plt.xlabel("$r$ / m")
    plt.ylabel("count at sea lvl." if primary=='iron' else '')
    plt.yscale("log")
    plt.ylim(1, 6e4)

    plot.save(plt.gcf(), f"eas-showers/{primary}")

    # break
# Out:
# 19:47:46 (   +6.7s) [DEBUG  ] -- font size set to 9.5
# 19:47:46 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 19:47:46 (    +0ms) [DEBUG  ] -- figure size set to [2.2, 2.5]
# 19:47:46 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 19:47:46 (    +0ms) [DEBUG  ] -- usetex set to False

# %%
data = pd.read_parquet(f"/home/filip/Public/CORSIKA8/1e17_epos_lhc_proton/particles/particles.parquet")
data
# Out:
#         shower  pdg  kinetic_energy           x           y        nx  \
# 0            0   22        0.056160 -405.128510  318.409882 -0.080877
# 1            0  -13        4.003055 -406.157715  204.188568 -0.070573
# 2            0   22        0.013905  318.174835 -117.297180  0.241331
# 3            0   22        0.271509  262.567535 -112.289619  0.061559
# 4            0   22        0.000512  269.843597 -181.674332  0.085467
# ...        ...  ...             ...         ...         ...       ...
# 203543       0   22        0.004081  320.826996  -13.514359  0.129738
# 203544       0   22        0.001470 -259.426697 -449.607147 -0.230813
# 203545       0   11        0.014671   -8.651050  140.958145  0.306577
# 203546       0   13       98.146782  -13.105893  145.376038 -0.001044
# 203547       0  -13       31.056080   -1.351213   57.956127 -0.001447
#
#               ny        nz      time  weight
# 0       0.253790 -0.963872  0.000376     1.0
# 1       0.021006 -0.997285  0.000376     1.0
# 2      -0.032007 -0.969915  0.000376     1.0
# 3      -0.031505 -0.997606  0.000376     1.0
# 4      -0.287298 -0.954021  0.000376     1.0
# ...          ...       ...       ...     ...
# 203543 -0.413612 -0.901162  0.000376     1.0
# 203544 -0.847802 -0.477448  0.000377     1.0
# 203545 -0.426395 -0.850998  0.000376     1.0
# 203546  0.014908 -0.999888  0.000376     1.0
# 203547  0.002749 -0.999995  0.000376     1.0
#
# [203548 rows x 10 columns]
