# %%
from utils.plotting import *
from utils.binaries import *
from utils.auger.fd import AperturePlot

# %%
ax = AperturePlot(filterStructure=False)

data = pd.read_csv("/home/filip/Public/xy-calibration/results/outPositionsComb_15675.txt")

ax.scatter(data.loc[12:len(data)-11, 'x'], data.loc[12:len(data)-11, 'y'], s=14, marker='h', c='w', alpha=0.4, ec='none')
ax.set_facecolor("k")
ax.set_xticks([])
ax.set_yticks([])
# ax.axis("off")
# Out:
# []

# %%
data
# Out:
#       Unnamed: 0         time    x    y  event_number  user_id  temp_led  \
# 0              0     0.000000  0.0  0.0             0        0      30.5
# 1              1     0.000000  0.0  0.0             0        0      30.5
# 2              2     0.000000  0.0  0.0             0        0      30.5
# 3              3     0.999823  0.0  0.0             1        1      30.5
# 4              4     2.010018  0.0  0.0             2        2      30.5
# ...          ...          ...  ...  ...           ...      ...       ...
# 1688        1688  3314.630242  0.0  0.0           816      816      29.5
# 1689        1689  3315.644624  0.0  0.0           817      817      29.5
# 1690        1690  3316.620418  0.0  0.0           818      818      29.5
# 1691        1691  3317.620695  0.0  0.0           819      819      29.5
# 1692        1692  3318.630839  0.0  0.0           820      820      29.5
#
#       temp_phd  temp_board  phd_signal   FDeventSum
# ...

# %%
data.loc[12:len(data)-11, 'x']
# Out:
# 12     -510.0
# 13     -450.0
# 14     -390.0
# 15     -330.0
# 16     -270.0
#         ...
# 1678    270.0
# 1679    330.0
# 1680    390.0
# 1681    450.0
# 1682    510.0
# Name: x, Length: 1671, dtype: float64
