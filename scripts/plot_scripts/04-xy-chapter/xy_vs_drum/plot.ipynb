# %%
from utils.binaries import *
from utils.plotting import *

from utils.auger.fd.XYScanner import Campaign
# Out:
# 02:56:24 (   +3.0s) [INFO   ] -- import logging
# 02:56:24 (   +80ms) [INFO   ] -- import numpy as np
# 02:56:24 (    +6ms) [INFO   ] -- import uncertainties
# 02:56:24 (  +206ms) [INFO   ] -- import pandas as pd
# 02:56:24 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 02:56:24 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 02:56:24 (    +1ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 02:56:24 (    +0ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 02:56:24 (    +0ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 02:56:24 (    +0ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 02:56:24 (    +1ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# 02:56:24 (    +0ms) [INFO   ] -- set OFLN_PATH = PosixPath('/home/filip/Public/offline/install')
# 02:56:24 (  +250ms) [INFO   ] -- import matplotlib.pyplot as plt
# ...

# %%
OfficialProd = Campaign(2024, 11)

# %%
OfficialProd.runs['LL3'] = Campaign(2022, 10).runs["LL3"]
OfficialProd.runs['HE1'] = Campaign(2023, 10).runs["HE1"]

# %%
print(OfficialProd['LL3'])
print(OfficialProd['HE1'])
print(OfficialProd['HE2'])
print(OfficialProd['HE3'])
# Out:
# LL3 @ 2022-10-24 w/ OLO: {'preDAQ': '15668m03', 'preXY': '15674', 'XY': '15675', 'postXY': '15676', 'postDAQ': '15681m03'}
# HE1 @ 2023-10-13 w/ OLO: {'preDAQ': '6018m25', 'preXY': '6019', 'XY': '6020x', 'postXY': '6023'}
# HE2 @ 2024-11-21 w/ OLO: {'preDAQ': '6511m26', 'preXY': '6515', 'XY': '6516', 'postXY': '6517'}
# HE3 @ 2024-11-21 w/ OLO: {'preDAQ': '6511m27', 'preXY': '6518', 'XY': '6519', 'postXY': '6520', 'postDAQ': '6524m27'}

# %%
fig = OfficialProd.plot_summary(normalize='cala', ymin=0.9, ymax=1.75)
